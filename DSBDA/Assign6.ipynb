# %%
# Data Visualization III 
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g., 
# https://archive.ics.uci.edu/ml/datasets/Iris). Scan the dataset and give the inference as: 
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset. 
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions. 
# 3. Create a box plot for each feature in the dataset. 
# 4. Compare distributions and identify outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset. 
for column in df.columns:
    print(column + ":")
    print(df[column].unique())
    print()
# Out:
# sepal_length:
# [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]
#
# sepal_width:
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]
#
# petal_length:
# [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]
#
# petal_width:
# [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]
#
# species:
# ['setosa' 'versicolor' 'virginica']

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions. 
fig,axes = plt.subplots(2,2,figsize=(10,10))

sns.histplot(data=df,x='sepal_length',bins=20,ax=axes[0,0])
sns.histplot(data=df,x='sepal_width',bins=20,ax=axes[0,1])
sns.histplot(data=df,x='petal_length',bins=20,ax=axes[1,0])
sns.histplot(data=df,x='petal_length',bins=20,ax=axes[1,1])

plt.show()

# %%
df['species'] = df['species'].replace({0:'Setosa',1:'Versicolor',2:'Virginica'})

# %%
# 3. Create a box plot for each feature in the dataset. 

fig,axes = plt.subplots(2,2,figsize=(10,10))

sns.boxplot(data=df,x='species',y='sepal_length',ax=axes[0,0])
sns.boxplot(data=df,x='species',y='sepal_width',ax=axes[0,1])
sns.boxplot(data=df,x='species',y='petal_length',ax=axes[1,0])
sns.boxplot(data=df,x='species',y='petal_length',ax=axes[1,1])

plt.show()

# %%
# 4. Compare distributions and identify outliers.

sns.scatterplot(x='sepal_length',y='sepal_width',hue='species',data=df)
plt.show()
